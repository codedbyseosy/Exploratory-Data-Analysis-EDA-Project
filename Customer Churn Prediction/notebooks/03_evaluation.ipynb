# %% [markdown]
# # Evaluation

# %% [markdown]
# ## 1. Import libraries

# %%
# --- Imports ---
import joblib
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score, classification_report, precision_recall_curve, average_precision_score, roc_auc_score, roc_curve

# %% [markdown]
# ## 2. Load datasets and models

# %%
import joblib

# Load the scaler 
scaler = joblib.load('/Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/saved_data/scaler.pkl')


# --- Load datasets ---
X_train = joblib.load('/Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/saved_data/X_train.pkl')
X_test = joblib.load('/Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/saved_data/X_test.pkl')
y_train = joblib.load('/Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/saved_data/y_train.pkl')
y_test = joblib.load('/Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/saved_data/y_test.pkl')


# --- Load trained models ---
lr = joblib.load('/Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/saved_models/LogisticRegression.pkl')
svc = joblib.load('/Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/saved_models/SVC.pkl')
dt = joblib.load('/Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/saved_models/DecisionTreeClassifier.pkl')
rf = joblib.load('/Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/saved_models/RandomForestClassifier.pkl')
xgb = joblib.load('/Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/saved_models/XGBClassifier.pkl')
cat = joblib.load('/Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/saved_models/CatBoostClassifier.pkl')


models = [lr, svc, dt, rf, xgb, cat]

# %% [markdown]
# ## 3. Stratified Cross-Validation (on Training Set)

# %%
# --- Set up stratified cross-validaion ---
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42) 

results = []

for model in models:
    print(f"\nCross-Validation Scores for {model.__class__.__name__}")

    # Evaluate model with corss-validation
    acc = cross_val_score(model, X_train, y_train, cv=skf, scoring='accuracy')
    precision = cross_val_score(model, X_train, y_train, cv=skf, scoring='precision')
    recall = cross_val_score(model, X_train, y_train, cv=skf, scoring='recall')
    f1 = cross_val_score(model, X_train, y_train, cv=skf, scoring="f1")
    auc_score = cross_val_score(model, X_train, y_train, cv=skf, scoring="roc_auc")
    avg_precision = cross_val_score(model, X_train, y_train, cv=skf, scoring="average_precision")


    results.append({
    'Model': model.__class__.__name__,
    'Accuracy': acc.mean(),
    'Precision': precision.mean(),
    'Recall': recall.mean(),
    'F1 Score': f1.mean(),
    'ROC AUC': auc_score.mean(),
    'PR AUC': avg_precision.mean()
    })
# Out:
# Cross-Validation Scores for LogisticRegression
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/eseoseodion/Documents/Portfolio/Customer Churn Prediction/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Cross-Validation Scores for SVC
#
# Cross-Validation Scores for DecisionTreeClassifier
#
# Cross-Validation Scores for RandomForestClassifier
#
# Cross-Validation Scores for XGBClassifier
#
# Cross-Validation Scores for CatBoostClassifier
# Learning rate set to 0.021794
# 0:	learn: 0.6813792	total: 54.4ms	remaining: 54.4s
# 1:	learn: 0.6714005	total: 56.7ms	remaining: 28.3s
# 2:	learn: 0.6601656	total: 59.7ms	remaining: 19.8s
# 3:	learn: 0.6495432	total: 61.9ms	remaining: 15.4s
# 4:	learn: 0.6388611	total: 63.9ms	remaining: 12.7s
# 5:	learn: 0.6299869	total: 65.9ms	remaining: 10.9s
# 6:	learn: 0.6200284	total: 68ms	remaining: 9.65s
# 7:	learn: 0.6113740	total: 70ms	remaining: 8.69s
# 8:	learn: 0.6025625	total: 72.2ms	remaining: 7.95s
# 9:	learn: 0.5950604	total: 74.4ms	remaining: 7.36s
# 10:	learn: 0.5877254	total: 76.4ms	remaining: 6.87s
# 11:	learn: 0.5810801	total: 78.5ms	remaining: 6.46s
# 12:	learn: 0.5743199	total: 80.5ms	remaining: 6.11s
# 13:	learn: 0.5683312	total: 82.5ms	remaining: 5.81s
# 14:	learn: 0.5621776	total: 84.7ms	remaining: 5.56s
# 15:	learn: 0.5557617	total: 86.7ms	remaining: 5.33s
# 16:	learn: 0.5496514	total: 88.7ms	remaining: 5.13s
# 17:	learn: 0.5436361	total: 91ms	remaining: 4.96s
# 18:	learn: 0.5376348	total: 93.1ms	remaining: 4.81s
# 19:	learn: 0.5325658	total: 95.2ms	remaining: 4.67s
# 20:	learn: 0.5278796	total: 97.5ms	remaining: 4.54s
# 21:	learn: 0.5236198	total: 99.8ms	remaining: 4.44s
# 22:	learn: 0.5184149	total: 102ms	remaining: 4.33s
# 23:	learn: 0.5136877	total: 104ms	remaining: 4.23s
# 24:	learn: 0.5098493	total: 106ms	remaining: 4.15s
# 25:	learn: 0.5047283	total: 109ms	remaining: 4.07s
# 26:	learn: 0.5011016	total: 111ms	remaining: 3.99s
# 27:	learn: 0.4959936	total: 113ms	remaining: 3.92s
# 28:	learn: 0.4928005	total: 115ms	remaining: 3.86s
# 29:	learn: 0.4893755	total: 117ms	remaining: 3.79s
# 30:	learn: 0.4860701	total: 119ms	remaining: 3.73s
# 31:	learn: 0.4827672	total: 122ms	remaining: 3.69s
# 32:	learn: 0.4798525	total: 124ms	remaining: 3.65s
# 33:	learn: 0.4766503	total: 127ms	remaining: 3.6s
# 34:	learn: 0.4736983	total: 129ms	remaining: 3.55s
# 35:	learn: 0.4703121	total: 131ms	remaining: 3.5s
# 36:	learn: 0.4672440	total: 133ms	remaining: 3.46s
# 37:	learn: 0.4644522	total: 135ms	remaining: 3.42s
# 38:	learn: 0.4620979	total: 137ms	remaining: 3.38s
# 39:	learn: 0.4591628	total: 139ms	remaining: 3.34s
# 40:	learn: 0.4565997	total: 141ms	remaining: 3.3s
# 41:	learn: 0.4547647	total: 143ms	remaining: 3.25s
# 42:	learn: 0.4528461	total: 144ms	remaining: 3.21s
# 43:	learn: 0.4501710	total: 146ms	remaining: 3.18s
# 44:	learn: 0.4477890	total: 148ms	remaining: 3.14s
# 45:	learn: 0.4443835	total: 150ms	remaining: 3.11s
# 46:	learn: 0.4421409	total: 152ms	remaining: 3.08s
# 47:	learn: 0.4400028	total: 154ms	remaining: 3.05s
# 48:	learn: 0.4379920	total: 155ms	remaining: 3.02s
# 49:	learn: 0.4364852	total: 157ms	remaining: 2.98s
# 50:	learn: 0.4344490	total: 159ms	remaining: 2.96s
# 51:	learn: 0.4330519	total: 161ms	remaining: 2.93s
# 52:	learn: 0.4307934	total: 162ms	remaining: 2.9s
# 53:	learn: 0.4281923	total: 164ms	remaining: 2.87s
# 54:	learn: 0.4265990	total: 166ms	remaining: 2.85s
# 55:	learn: 0.4248412	total: 168ms	remaining: 2.82s
# 56:	learn: 0.4232888	total: 169ms	remaining: 2.8s
# 57:	learn: 0.4216824	total: 171ms	remaining: 2.78s
# 58:	learn: 0.4201366	total: 173ms	remaining: 2.77s
# 59:	learn: 0.4187208	total: 175ms	remaining: 2.74s
# 60:	learn: 0.4174780	total: 177ms	remaining: 2.72s
# 61:	learn: 0.4163468	total: 179ms	remaining: 2.7s
# 62:	learn: 0.4148493	total: 180ms	remaining: 2.68s
# 63:	learn: 0.4137959	total: 182ms	remaining: 2.66s
# 64:	learn: 0.4124318	total: 184ms	remaining: 2.65s
# 65:	learn: 0.4110749	total: 186ms	remaining: 2.63s
# 66:	learn: 0.4094600	total: 187ms	remaining: 2.61s
# 67:	learn: 0.4085161	total: 189ms	remaining: 2.59s
# 68:	learn: 0.4074539	total: 191ms	remaining: 2.58s
# 69:	learn: 0.4061101	total: 193ms	remaining: 2.56s
# 70:	learn: 0.4050725	total: 194ms	remaining: 2.54s
# 71:	learn: 0.4038264	total: 196ms	remaining: 2.53s
# 72:	learn: 0.4022885	total: 198ms	remaining: 2.52s
# 73:	learn: 0.4010447	total: 201ms	remaining: 2.52s
# 74:	learn: 0.3993392	total: 203ms	remaining: 2.5s
# 75:	learn: 0.3986754	total: 205ms	remaining: 2.49s
# 76:	learn: 0.3972671	total: 207ms	remaining: 2.48s
# 77:	learn: 0.3959223	total: 208ms	remaining: 2.46s
# 78:	learn: 0.3949577	total: 210ms	remaining: 2.45s
# 79:	learn: 0.3940659	total: 212ms	remaining: 2.44s
# 80:	learn: 0.3928898	total: 214ms	remaining: 2.42s
# 81:	learn: 0.3923186	total: 215ms	remaining: 2.41s
# 82:	learn: 0.3912912	total: 217ms	remaining: 2.4s
# 83:	learn: 0.3901331	total: 219ms	remaining: 2.39s
# 84:	learn: 0.3893045	total: 221ms	remaining: 2.38s
# 85:	learn: 0.3883225	total: 222ms	remaining: 2.36s
# 86:	learn: 0.3875505	total: 224ms	remaining: 2.35s
# 87:	learn: 0.3868799	total: 226ms	remaining: 2.34s
# 88:	learn: 0.3860982	total: 228ms	remaining: 2.33s
# 89:	learn: 0.3855125	total: 229ms	remaining: 2.32s
# 90:	learn: 0.3845944	total: 231ms	remaining: 2.31s
# 91:	learn: 0.3837137	total: 233ms	remaining: 2.3s
# 92:	learn: 0.3828678	total: 235ms	remaining: 2.29s
# 93:	learn: 0.3820159	total: 237ms	remaining: 2.28s
# 94:	learn: 0.3815902	total: 238ms	remaining: 2.27s
# 95:	learn: 0.3811445	total: 240ms	remaining: 2.26s
# 96:	learn: 0.3807156	total: 242ms	remaining: 2.25s
# 97:	learn: 0.3802583	total: 244ms	remaining: 2.24s
# 98:	learn: 0.3797335	total: 246ms	remaining: 2.24s
# 99:	learn: 0.3790094	total: 248ms	remaining: 2.23s
# 100:	learn: 0.3786705	total: 249ms	remaining: 2.22s
# 101:	learn: 0.3782307	total: 251ms	remaining: 2.21s
# 102:	learn: 0.3776030	total: 253ms	remaining: 2.2s
# 103:	learn: 0.3767944	total: 255ms	remaining: 2.19s
# 104:	learn: 0.3763760	total: 256ms	remaining: 2.19s
# 105:	learn: 0.3758230	total: 258ms	remaining: 2.18s
# 106:	learn: 0.3751022	total: 260ms	remaining: 2.17s
# 107:	learn: 0.3743500	total: 262ms	remaining: 2.16s
# 108:	learn: 0.3735559	total: 263ms	remaining: 2.15s
# 109:	learn: 0.3730416	total: 265ms	remaining: 2.15s
# 110:	learn: 0.3724261	total: 267ms	remaining: 2.14s
# 111:	learn: 0.3721499	total: 269ms	remaining: 2.13s
# 112:	learn: 0.3718284	total: 270ms	remaining: 2.12s
# 113:	learn: 0.3710800	total: 272ms	remaining: 2.11s
# 114:	learn: 0.3702841	total: 274ms	remaining: 2.11s
# 115:	learn: 0.3698292	total: 276ms	remaining: 2.1s
# 116:	learn: 0.3693458	total: 277ms	remaining: 2.09s
# 117:	learn: 0.3686290	total: 280ms	remaining: 2.09s
# 118:	learn: 0.3681944	total: 281ms	remaining: 2.08s
# 119:	learn: 0.3677950	total: 283ms	remaining: 2.08s
# 120:	learn: 0.3673611	total: 285ms	remaining: 2.07s
# 121:	learn: 0.3670185	total: 287ms	remaining: 2.06s
# 122:	learn: 0.3666184	total: 288ms	remaining: 2.06s
# 123:	learn: 0.3658865	total: 290ms	remaining: 2.05s
# 124:	learn: 0.3655826	total: 292ms	remaining: 2.04s
# 125:	learn: 0.3648575	total: 294ms	remaining: 2.04s
# 126:	learn: 0.3645409	total: 296ms	remaining: 2.03s
# 127:	learn: 0.3640744	total: 297ms	remaining: 2.02s
# 128:	learn: 0.3635020	total: 299ms	remaining: 2.02s
# 129:	learn: 0.3632393	total: 301ms	remaining: 2.01s
# 130:	learn: 0.3625334	total: 303ms	remaining: 2.01s
# 131:	learn: 0.3622067	total: 304ms	remaining: 2s
# 132:	learn: 0.3616532	total: 306ms	remaining: 2s
# 133:	learn: 0.3612255	total: 308ms	remaining: 1.99s
# 134:	learn: 0.3609677	total: 310ms	remaining: 1.99s
# 135:	learn: 0.3606081	total: 312ms	remaining: 1.98s
# 136:	learn: 0.3602465	total: 313ms	remaining: 1.97s
# 137:	learn: 0.3597470	total: 315ms	remaining: 1.97s
# 138:	learn: 0.3593489	total: 317ms	remaining: 1.96s
# 139:	learn: 0.3589567	total: 319ms	remaining: 1.96s
# 140:	learn: 0.3585320	total: 321ms	remaining: 1.95s
# 141:	learn: 0.3580491	total: 323ms	remaining: 1.95s
# 142:	learn: 0.3577633	total: 325ms	remaining: 1.95s
# 143:	learn: 0.3571101	total: 326ms	remaining: 1.94s
# 144:	learn: 0.3566676	total: 329ms	remaining: 1.94s
# 145:	learn: 0.3560455	total: 330ms	remaining: 1.93s
# 146:	learn: 0.3554124	total: 332ms	remaining: 1.93s
# 147:	learn: 0.3550366	total: 334ms	remaining: 1.92s
# 148:	learn: 0.3546771	total: 336ms	remaining: 1.92s
# 149:	learn: 0.3543160	total: 337ms	remaining: 1.91s
# 150:	learn: 0.3540513	total: 339ms	remaining: 1.91s
# 151:	learn: 0.3538687	total: 342ms	remaining: 1.91s
# 152:	learn: 0.3536378	total: 344ms	remaining: 1.9s
# 153:	learn: 0.3532055	total: 346ms	remaining: 1.9s
# 154:	learn: 0.3528658	total: 347ms	remaining: 1.89s
# 155:	learn: 0.3525538	total: 349ms	remaining: 1.89s
# 156:	learn: 0.3523215	total: 351ms	remaining: 1.88s
# 157:	learn: 0.3521649	total: 353ms	remaining: 1.88s
# 158:	learn: 0.3517603	total: 355ms	remaining: 1.88s
# 159:	learn: 0.3513062	total: 357ms	remaining: 1.87s
# 160:	learn: 0.3510470	total: 358ms	remaining: 1.87s
# 161:	learn: 0.3507569	total: 360ms	remaining: 1.86s
# 162:	learn: 0.3504228	total: 362ms	remaining: 1.86s
# 163:	learn: 0.3500082	total: 363ms	remaining: 1.85s
# 164:	learn: 0.3497949	total: 365ms	remaining: 1.85s
# 165:	learn: 0.3496245	total: 367ms	remaining: 1.84s
# 166:	learn: 0.3491675	total: 369ms	remaining: 1.84s
# 167:	learn: 0.3489456	total: 371ms	remaining: 1.83s
# 168:	learn: 0.3485556	total: 372ms	remaining: 1.83s
# 169:	learn: 0.3483326	total: 374ms	remaining: 1.83s
# 170:	learn: 0.3481222	total: 376ms	remaining: 1.82s
# 171:	learn: 0.3479157	total: 378ms	remaining: 1.82s
# 172:	learn: 0.3476824	total: 379ms	remaining: 1.81s
# 173:	learn: 0.3474990	total: 381ms	remaining: 1.81s
# 174:	learn: 0.3473100	total: 383ms	remaining: 1.81s
# 175:	learn: 0.3471993	total: 385ms	remaining: 1.8s
# 176:	learn: 0.3470518	total: 387ms	remaining: 1.8s
# 177:	learn: 0.3469121	total: 389ms	remaining: 1.8s
# 178:	learn: 0.3467916	total: 391ms	remaining: 1.79s
# 179:	learn: 0.3464747	total: 393ms	remaining: 1.79s
# 180:	learn: 0.3463235	total: 395ms	remaining: 1.79s
# 181:	learn: 0.3458968	total: 397ms	remaining: 1.78s
# 182:	learn: 0.3457271	total: 399ms	remaining: 1.78s
# 183:	learn: 0.3454428	total: 401ms	remaining: 1.78s
# 184:	learn: 0.3451784	total: 403ms	remaining: 1.77s
# 185:	learn: 0.3450236	total: 405ms	remaining: 1.77s
# 186:	learn: 0.3446836	total: 407ms	remaining: 1.77s
# 187:	learn: 0.3445941	total: 408ms	remaining: 1.76s
# 188:	learn: 0.3443885	total: 410ms	remaining: 1.76s
# 189:	learn: 0.3441367	total: 412ms	remaining: 1.76s
# 190:	learn: 0.3440424	total: 414ms	remaining: 1.75s
# 191:	learn: 0.3436485	total: 416ms	remaining: 1.75s
# 192:	learn: 0.3434399	total: 418ms	remaining: 1.75s
# 193:	learn: 0.3432890	total: 420ms	remaining: 1.75s
# 194:	learn: 0.3431836	total: 422ms	remaining: 1.74s
# 195:	learn: 0.3430174	total: 424ms	remaining: 1.74s
# 196:	learn: 0.3428359	total: 425ms	remaining: 1.73s
# 197:	learn: 0.3425843	total: 427ms	remaining: 1.73s
# 198:	learn: 0.3424674	total: 429ms	remaining: 1.73s
# 199:	learn: 0.3422612	total: 431ms	remaining: 1.72s
# 200:	learn: 0.3420776	total: 433ms	remaining: 1.72s
# 201:	learn: 0.3420215	total: 435ms	remaining: 1.72s
# 202:	learn: 0.3417706	total: 437ms	remaining: 1.72s
# 203:	learn: 0.3415385	total: 439ms	remaining: 1.71s
# 204:	learn: 0.3413651	total: 440ms	remaining: 1.71s
# 205:	learn: 0.3411775	total: 442ms	remaining: 1.7s
# 206:	learn: 0.3409675	total: 444ms	remaining: 1.7s
# 207:	learn: 0.3406546	total: 446ms	remaining: 1.7s
# 208:	learn: 0.3405121	total: 447ms	remaining: 1.69s
# 209:	learn: 0.3402472	total: 449ms	remaining: 1.69s
# 210:	learn: 0.3401251	total: 452ms	remaining: 1.69s
# 211:	learn: 0.3399361	total: 453ms	remaining: 1.68s
# 212:	learn: 0.3398478	total: 455ms	remaining: 1.68s
# 213:	learn: 0.3395884	total: 457ms	remaining: 1.68s
# 214:	learn: 0.3393208	total: 459ms	remaining: 1.67s
# 215:	learn: 0.3389424	total: 460ms	remaining: 1.67s
# 216:	learn: 0.3388125	total: 462ms	remaining: 1.67s
# 217:	learn: 0.3385796	total: 464ms	remaining: 1.67s
# 218:	learn: 0.3382640	total: 467ms	remaining: 1.66s
# 219:	learn: 0.3380497	total: 468ms	remaining: 1.66s
# 220:	learn: 0.3378441	total: 470ms	remaining: 1.66s
# 221:	learn: 0.3376090	total: 472ms	remaining: 1.65s
# 222:	learn: 0.3374843	total: 474ms	remaining: 1.65s
# 223:	learn: 0.3373731	total: 476ms	remaining: 1.65s
# 224:	learn: 0.3371400	total: 478ms	remaining: 1.65s
# 225:	learn: 0.3368866	total: 480ms	remaining: 1.64s
# 226:	learn: 0.3367070	total: 482ms	remaining: 1.64s
# 227:	learn: 0.3365209	total: 484ms	remaining: 1.64s
# 228:	learn: 0.3363486	total: 486ms	remaining: 1.64s
# 229:	learn: 0.3362206	total: 488ms	remaining: 1.63s
# 230:	learn: 0.3360365	total: 489ms	remaining: 1.63s
# 231:	learn: 0.3358275	total: 491ms	remaining: 1.63s
# 232:	learn: 0.3353926	total: 493ms	remaining: 1.62s
# 233:	learn: 0.3351211	total: 495ms	remaining: 1.62s
# 234:	learn: 0.3348187	total: 497ms	remaining: 1.62s
# 235:	learn: 0.3345675	total: 498ms	remaining: 1.61s
# 236:	learn: 0.3342919	total: 500ms	remaining: 1.61s
# 237:	learn: 0.3341363	total: 502ms	remaining: 1.61s
# 238:	learn: 0.3339917	total: 504ms	remaining: 1.6s
# 239:	learn: 0.3338671	total: 505ms	remaining: 1.6s
# 240:	learn: 0.3337425	total: 507ms	remaining: 1.6s
# 241:	learn: 0.3336586	total: 509ms	remaining: 1.59s
# 242:	learn: 0.3335532	total: 511ms	remaining: 1.59s
# 243:	learn: 0.3333783	total: 513ms	remaining: 1.59s
# 244:	learn: 0.3332175	total: 514ms	remaining: 1.58s
# 245:	learn: 0.3330770	total: 516ms	remaining: 1.58s
# 246:	learn: 0.3327992	total: 518ms	remaining: 1.58s
# 247:	learn: 0.3325094	total: 520ms	remaining: 1.58s
# 248:	learn: 0.3323486	total: 522ms	remaining: 1.57s
# 249:	learn: 0.3322403	total: 524ms	remaining: 1.57s
# 250:	learn: 0.3320645	total: 526ms	remaining: 1.57s
# 251:	learn: 0.3318820	total: 528ms	remaining: 1.57s
# 252:	learn: 0.3317172	total: 530ms	remaining: 1.56s
# 253:	learn: 0.3314915	total: 531ms	remaining: 1.56s
# 254:	learn: 0.3311235	total: 533ms	remaining: 1.56s
# 255:	learn: 0.3309782	total: 535ms	remaining: 1.55s
# 256:	learn: 0.3308964	total: 537ms	remaining: 1.55s
# 257:	learn: 0.3307523	total: 539ms	remaining: 1.55s
# 258:	learn: 0.3305743	total: 541ms	remaining: 1.55s
# 259:	learn: 0.3304461	total: 543ms	remaining: 1.54s
# 260:	learn: 0.3303055	total: 544ms	remaining: 1.54s
# 261:	learn: 0.3302130	total: 546ms	remaining: 1.54s
# 262:	learn: 0.3301212	total: 548ms	remaining: 1.53s
# 263:	learn: 0.3299704	total: 550ms	remaining: 1.53s
# 264:	learn: 0.3298790	total: 551ms	remaining: 1.53s
# 265:	learn: 0.3297391	total: 553ms	remaining: 1.53s
# 266:	learn: 0.3296103	total: 555ms	remaining: 1.52s
# 267:	learn: 0.3293996	total: 557ms	remaining: 1.52s
# 268:	learn: 0.3293328	total: 560ms	remaining: 1.52s
# 269:	learn: 0.3292764	total: 562ms	remaining: 1.52s
# 270:	learn: 0.3290259	total: 563ms	remaining: 1.51s
# 271:	learn: 0.3288605	total: 565ms	remaining: 1.51s
# 272:	learn: 0.3287384	total: 568ms	remaining: 1.51s
# 273:	learn: 0.3286553	total: 569ms	remaining: 1.51s
# 274:	learn: 0.3285629	total: 571ms	remaining: 1.51s
# 275:	learn: 0.3284356	total: 574ms	remaining: 1.5s
# 276:	learn: 0.3282756	total: 576ms	remaining: 1.5s
# 277:	learn: 0.3280565	total: 578ms	remaining: 1.5s
# 278:	learn: 0.3278903	total: 579ms	remaining: 1.5s
# 279:	learn: 0.3277229	total: 581ms	remaining: 1.5s
# 280:	learn: 0.3275891	total: 583ms	remaining: 1.49s
# 281:	learn: 0.3273648	total: 585ms	remaining: 1.49s
# 282:	learn: 0.3271619	total: 587ms	remaining: 1.49s
# 283:	learn: 0.3270316	total: 589ms	remaining: 1.48s
# 284:	learn: 0.3269326	total: 591ms	remaining: 1.48s
# 285:	learn: 0.3268078	total: 593ms	remaining: 1.48s
# 286:	learn: 0.3266976	total: 595ms	remaining: 1.48s
# 287:	learn: 0.3265002	total: 597ms	remaining: 1.48s
# 288:	learn: 0.3261686	total: 599ms	remaining: 1.47s
# 289:	learn: 0.3259698	total: 600ms	remaining: 1.47s
# 290:	learn: 0.3258464	total: 602ms	remaining: 1.47s
# 291:	learn: 0.3256769	total: 604ms	remaining: 1.47s
# 292:	learn: 0.3254859	total: 607ms	remaining: 1.46s
# 293:	learn: 0.3253814	total: 609ms	remaining: 1.46s
# 294:	learn: 0.3252030	total: 611ms	remaining: 1.46s
# 295:	learn: 0.3250069	total: 612ms	remaining: 1.46s
# 296:	learn: 0.3248230	total: 614ms	remaining: 1.45s
# 297:	learn: 0.3247285	total: 616ms	remaining: 1.45s
# 298:	learn: 0.3245839	total: 618ms	remaining: 1.45s
# 299:	learn: 0.3244893	total: 620ms	remaining: 1.45s
# 300:	learn: 0.3243532	total: 622ms	remaining: 1.44s
# 301:	learn: 0.3242351	total: 624ms	remaining: 1.44s
# 302:	learn: 0.3241362	total: 626ms	remaining: 1.44s
# 303:	learn: 0.3239976	total: 628ms	remaining: 1.44s
# 304:	learn: 0.3239222	total: 629ms	remaining: 1.43s
# 305:	learn: 0.3237748	total: 631ms	remaining: 1.43s
# 306:	learn: 0.3235610	total: 633ms	remaining: 1.43s
# 307:	learn: 0.3234440	total: 635ms	remaining: 1.43s
# 308:	learn: 0.3233706	total: 637ms	remaining: 1.42s
# 309:	learn: 0.3232249	total: 639ms	remaining: 1.42s
# 310:	learn: 0.3231718	total: 640ms	remaining: 1.42s
# 311:	learn: 0.3231194	total: 642ms	remaining: 1.42s
# 312:	learn: 0.3230011	total: 644ms	remaining: 1.41s
# 313:	learn: 0.3228252	total: 646ms	remaining: 1.41s
# 314:	learn: 0.3226468	total: 648ms	remaining: 1.41s
# 315:	learn: 0.3224746	total: 650ms	remaining: 1.41s
# 316:	learn: 0.3224129	total: 652ms	remaining: 1.41s
# 317:	learn: 0.3223120	total: 654ms	remaining: 1.4s
# 318:	learn: 0.3222311	total: 656ms	remaining: 1.4s
# 319:	learn: 0.3220643	total: 658ms	remaining: 1.4s
# 320:	learn: 0.3219988	total: 660ms	remaining: 1.4s
# 321:	learn: 0.3219317	total: 661ms	remaining: 1.39s
# 322:	learn: 0.3218216	total: 663ms	remaining: 1.39s
# 323:	learn: 0.3216194	total: 665ms	remaining: 1.39s
# 324:	learn: 0.3215326	total: 667ms	remaining: 1.39s
# 325:	learn: 0.3214526	total: 669ms	remaining: 1.38s
# 326:	learn: 0.3213115	total: 671ms	remaining: 1.38s
# 327:	learn: 0.3212507	total: 673ms	remaining: 1.38s
# 328:	learn: 0.3211884	total: 675ms	remaining: 1.38s
# 329:	learn: 0.3210640	total: 677ms	remaining: 1.37s
# 330:	learn: 0.3209278	total: 679ms	remaining: 1.37s
# 331:	learn: 0.3208231	total: 681ms	remaining: 1.37s
# 332:	learn: 0.3207500	total: 683ms	remaining: 1.37s
# 333:	learn: 0.3206228	total: 684ms	remaining: 1.36s
# 334:	learn: 0.3204623	total: 686ms	remaining: 1.36s
# 335:	learn: 0.3202919	total: 688ms	remaining: 1.36s
# 336:	learn: 0.3201421	total: 690ms	remaining: 1.36s
# 337:	learn: 0.3200256	total: 691ms	remaining: 1.35s
# 338:	learn: 0.3198384	total: 693ms	remaining: 1.35s
# 339:	learn: 0.3196973	total: 695ms	remaining: 1.35s
# 340:	learn: 0.3195526	total: 697ms	remaining: 1.35s
# 341:	learn: 0.3194218	total: 700ms	remaining: 1.34s
# 342:	learn: 0.3192810	total: 701ms	remaining: 1.34s
# 343:	learn: 0.3191381	total: 703ms	remaining: 1.34s
# 344:	learn: 0.3189777	total: 705ms	remaining: 1.34s
# 345:	learn: 0.3188441	total: 707ms	remaining: 1.34s
# 346:	learn: 0.3186614	total: 709ms	remaining: 1.33s
# 347:	learn: 0.3186044	total: 711ms	remaining: 1.33s
# 348:	learn: 0.3184963	total: 713ms	remaining: 1.33s
# 349:	learn: 0.3183757	total: 715ms	remaining: 1.33s
# 350:	learn: 0.3182756	total: 717ms	remaining: 1.32s
# 351:	learn: 0.3181774	total: 718ms	remaining: 1.32s
# 352:	learn: 0.3180691	total: 720ms	remaining: 1.32s
# 353:	learn: 0.3179240	total: 722ms	remaining: 1.32s
# 354:	learn: 0.3178507	total: 724ms	remaining: 1.31s
# 355:	learn: 0.3177378	total: 725ms	remaining: 1.31s
# 356:	learn: 0.3176544	total: 727ms	remaining: 1.31s
# 357:	learn: 0.3175128	total: 730ms	remaining: 1.31s
# 358:	learn: 0.3174300	total: 731ms	remaining: 1.3s
# 359:	learn: 0.3171933	total: 733ms	remaining: 1.3s
# 360:	learn: 0.3170760	total: 735ms	remaining: 1.3s
# 361:	learn: 0.3170184	total: 737ms	remaining: 1.3s
# 362:	learn: 0.3169000	total: 739ms	remaining: 1.3s
# 363:	learn: 0.3167657	total: 740ms	remaining: 1.29s
# 364:	learn: 0.3166917	total: 742ms	remaining: 1.29s
# 365:	learn: 0.3165623	total: 744ms	remaining: 1.29s
# 366:	learn: 0.3164832	total: 746ms	remaining: 1.29s
# 367:	learn: 0.3163627	total: 748ms	remaining: 1.28s
# 368:	learn: 0.3162641	total: 750ms	remaining: 1.28s
# 369:	learn: 0.3161504	total: 752ms	remaining: 1.28s
# 370:	learn: 0.3160974	total: 754ms	remaining: 1.28s
# 371:	learn: 0.3158935	total: 756ms	remaining: 1.27s
# 372:	learn: 0.3157500	total: 758ms	remaining: 1.27s
# 373:	learn: 0.3155932	total: 760ms	remaining: 1.27s
# 374:	learn: 0.3155112	total: 762ms	remaining: 1.27s
# 375:	learn: 0.3153902	total: 764ms	remaining: 1.27s
# 376:	learn: 0.3152187	total: 766ms	remaining: 1.26s
# 377:	learn: 0.3151334	total: 767ms	remaining: 1.26s
# 378:	learn: 0.3148844	total: 769ms	remaining: 1.26s
# 379:	learn: 0.3147321	total: 771ms	remaining: 1.26s
# 380:	learn: 0.3147045	total: 773ms	remaining: 1.25s
# 381:	learn: 0.3145396	total: 776ms	remaining: 1.25s
# 382:	learn: 0.3144046	total: 778ms	remaining: 1.25s
# 383:	learn: 0.3142077	total: 780ms	remaining: 1.25s
# 384:	learn: 0.3141453	total: 782ms	remaining: 1.25s
# 385:	learn: 0.3140120	total: 784ms	remaining: 1.25s
# 386:	learn: 0.3139236	total: 786ms	remaining: 1.24s
# 387:	learn: 0.3137947	total: 788ms	remaining: 1.24s
# 388:	learn: 0.3136448	total: 790ms	remaining: 1.24s
# 389:	learn: 0.3134584	total: 792ms	remaining: 1.24s
# 390:	learn: 0.3132407	total: 794ms	remaining: 1.24s
# 391:	learn: 0.3131315	total: 796ms	remaining: 1.23s
# 392:	learn: 0.3129954	total: 798ms	remaining: 1.23s
# 393:	learn: 0.3128506	total: 799ms	remaining: 1.23s
# 394:	learn: 0.3127241	total: 801ms	remaining: 1.23s
# 395:	learn: 0.3125546	total: 803ms	remaining: 1.23s
# 396:	learn: 0.3124411	total: 805ms	remaining: 1.22s
# 397:	learn: 0.3122980	total: 807ms	remaining: 1.22s
# 398:	learn: 0.3121885	total: 809ms	remaining: 1.22s
# 399:	learn: 0.3121300	total: 811ms	remaining: 1.22s
# 400:	learn: 0.3120211	total: 813ms	remaining: 1.21s
# 401:	learn: 0.3118457	total: 815ms	remaining: 1.21s
# 402:	learn: 0.3117278	total: 816ms	remaining: 1.21s
# 403:	learn: 0.3115538	total: 818ms	remaining: 1.21s
# 404:	learn: 0.3114389	total: 820ms	remaining: 1.2s
# 405:	learn: 0.3113623	total: 822ms	remaining: 1.2s
# 406:	learn: 0.3112589	total: 824ms	remaining: 1.2s
# 407:	learn: 0.3111571	total: 826ms	remaining: 1.2s
# 408:	learn: 0.3109961	total: 828ms	remaining: 1.2s
# 409:	learn: 0.3108767	total: 829ms	remaining: 1.19s
# 410:	learn: 0.3107196	total: 831ms	remaining: 1.19s
# 411:	learn: 0.3105765	total: 833ms	remaining: 1.19s
# 412:	learn: 0.3104471	total: 835ms	remaining: 1.19s
# 413:	learn: 0.3102563	total: 837ms	remaining: 1.19s
# 414:	learn: 0.3101185	total: 839ms	remaining: 1.18s
# 415:	learn: 0.3099981	total: 841ms	remaining: 1.18s
# 416:	learn: 0.3099276	total: 843ms	remaining: 1.18s
# 417:	learn: 0.3097753	total: 845ms	remaining: 1.18s
# 418:	learn: 0.3096396	total: 847ms	remaining: 1.17s
# 419:	learn: 0.3095033	total: 848ms	remaining: 1.17s
# 420:	learn: 0.3094180	total: 850ms	remaining: 1.17s
# 421:	learn: 0.3093187	total: 852ms	remaining: 1.17s
# 422:	learn: 0.3091557	total: 854ms	remaining: 1.16s
# 423:	learn: 0.3090740	total: 856ms	remaining: 1.16s
# 424:	learn: 0.3089435	total: 857ms	remaining: 1.16s
# 425:	learn: 0.3088270	total: 859ms	remaining: 1.16s
# 426:	learn: 0.3087165	total: 861ms	remaining: 1.16s
# 427:	learn: 0.3086009	total: 863ms	remaining: 1.15s
# 428:	learn: 0.3084754	total: 865ms	remaining: 1.15s
# 429:	learn: 0.3083706	total: 867ms	remaining: 1.15s
# 430:	learn: 0.3082440	total: 869ms	remaining: 1.15s
# 431:	learn: 0.3081371	total: 870ms	remaining: 1.14s
# 432:	learn: 0.3080039	total: 872ms	remaining: 1.14s
# 433:	learn: 0.3078613	total: 874ms	remaining: 1.14s
# 434:	learn: 0.3077012	total: 876ms	remaining: 1.14s
# 435:	learn: 0.3075023	total: 878ms	remaining: 1.14s
# 436:	learn: 0.3073597	total: 879ms	remaining: 1.13s
# 437:	learn: 0.3072758	total: 882ms	remaining: 1.13s
# 438:	learn: 0.3070762	total: 884ms	remaining: 1.13s
# 439:	learn: 0.3070099	total: 886ms	remaining: 1.13s
# 440:	learn: 0.3068557	total: 888ms	remaining: 1.13s
# 441:	learn: 0.3067729	total: 890ms	remaining: 1.12s
# 442:	learn: 0.3066419	total: 892ms	remaining: 1.12s
# 443:	learn: 0.3065474	total: 894ms	remaining: 1.12s
# 444:	learn: 0.3064749	total: 896ms	remaining: 1.12s
# 445:	learn: 0.3063565	total: 898ms	remaining: 1.11s
# 446:	learn: 0.3062466	total: 900ms	remaining: 1.11s
# 447:	learn: 0.3061732	total: 902ms	remaining: 1.11s
# 448:	learn: 0.3060984	total: 904ms	remaining: 1.11s
# 449:	learn: 0.3059479	total: 906ms	remaining: 1.11s
# 450:	learn: 0.3057232	total: 908ms	remaining: 1.1s
# 451:	learn: 0.3055528	total: 910ms	remaining: 1.1s
# 452:	learn: 0.3054317	total: 912ms	remaining: 1.1s
# 453:	learn: 0.3052798	total: 914ms	remaining: 1.1s
# 454:	learn: 0.3051820	total: 917ms	remaining: 1.1s
# 455:	learn: 0.3049651	total: 919ms	remaining: 1.09s
# 456:	learn: 0.3048309	total: 921ms	remaining: 1.09s
# 457:	learn: 0.3047443	total: 923ms	remaining: 1.09s
# 458:	learn: 0.3045979	total: 925ms	remaining: 1.09s
# 459:	learn: 0.3044604	total: 927ms	remaining: 1.09s
# 460:	learn: 0.3042711	total: 929ms	remaining: 1.08s
# 461:	learn: 0.3041056	total: 931ms	remaining: 1.08s
# 462:	learn: 0.3039551	total: 933ms	remaining: 1.08s
# 463:	learn: 0.3038715	total: 935ms	remaining: 1.08s
# 464:	learn: 0.3037907	total: 937ms	remaining: 1.08s
# 465:	learn: 0.3036687	total: 939ms	remaining: 1.07s
# 466:	learn: 0.3035006	total: 940ms	remaining: 1.07s
# 467:	learn: 0.3034154	total: 942ms	remaining: 1.07s
# 468:	learn: 0.3033217	total: 944ms	remaining: 1.07s
# 469:	learn: 0.3032123	total: 946ms	remaining: 1.07s
# 470:	learn: 0.3030320	total: 948ms	remaining: 1.06s
# 471:	learn: 0.3029346	total: 950ms	remaining: 1.06s
# 472:	learn: 0.3028104	total: 952ms	remaining: 1.06s
# 473:	learn: 0.3026759	total: 954ms	remaining: 1.06s
# 474:	learn: 0.3026057	total: 956ms	remaining: 1.06s
# 475:	learn: 0.3025448	total: 958ms	remaining: 1.05s
# 476:	learn: 0.3024173	total: 961ms	remaining: 1.05s
# 477:	learn: 0.3023190	total: 963ms	remaining: 1.05s
# 478:	learn: 0.3022130	total: 965ms	remaining: 1.05s
# 479:	learn: 0.3020899	total: 967ms	remaining: 1.05s
# 480:	learn: 0.3019781	total: 969ms	remaining: 1.04s
# 481:	learn: 0.3018489	total: 971ms	remaining: 1.04s
# 482:	learn: 0.3017169	total: 972ms	remaining: 1.04s
# 483:	learn: 0.3015502	total: 974ms	remaining: 1.04s
# 484:	learn: 0.3013869	total: 977ms	remaining: 1.04s
# 485:	learn: 0.3013150	total: 978ms	remaining: 1.03s
# 486:	learn: 0.3012097	total: 980ms	remaining: 1.03s
# 487:	learn: 0.3011326	total: 982ms	remaining: 1.03s
# 488:	learn: 0.3010258	total: 984ms	remaining: 1.03s
# 489:	learn: 0.3009453	total: 986ms	remaining: 1.02s
# 490:	learn: 0.3008338	total: 987ms	remaining: 1.02s
# 491:	learn: 0.3007346	total: 989ms	remaining: 1.02s
# 492:	learn: 0.3006048	total: 991ms	remaining: 1.02s
# 493:	learn: 0.3005364	total: 994ms	remaining: 1.02s
# 494:	learn: 0.3004436	total: 995ms	remaining: 1.01s
# 495:	learn: 0.3003276	total: 997ms	remaining: 1.01s
# 496:	learn: 0.3002195	total: 999ms	remaining: 1.01s
# 497:	learn: 0.3000460	total: 1s	remaining: 1.01s
# 498:	learn: 0.2998966	total: 1s	remaining: 1.01s
# 499:	learn: 0.2997844	total: 1s	remaining: 1s
# 500:	learn: 0.2996990	total: 1.01s	remaining: 1s
# 501:	learn: 0.2995496	total: 1.01s	remaining: 1s
# 502:	learn: 0.2994271	total: 1.01s	remaining: 998ms
# 503:	learn: 0.2993507	total: 1.01s	remaining: 996ms
# 504:	learn: 0.2992708	total: 1.01s	remaining: 994ms
# 505:	learn: 0.2991584	total: 1.01s	remaining: 991ms
# 506:	learn: 0.2989839	total: 1.02s	remaining: 989ms
# 507:	learn: 0.2989230	total: 1.02s	remaining: 987ms
# 508:	learn: 0.2988505	total: 1.02s	remaining: 984ms
# 509:	learn: 0.2987258	total: 1.02s	remaining: 983ms
# 510:	learn: 0.2986123	total: 1.02s	remaining: 981ms
# 511:	learn: 0.2985002	total: 1.03s	remaining: 978ms
# 512:	learn: 0.2983981	total: 1.03s	remaining: 976ms
# 513:	learn: 0.2982310	total: 1.03s	remaining: 974ms
# 514:	learn: 0.2981455	total: 1.03s	remaining: 972ms
# 515:	learn: 0.2980491	total: 1.03s	remaining: 969ms
# 516:	learn: 0.2979774	total: 1.03s	remaining: 967ms
# 517:	learn: 0.2978910	total: 1.04s	remaining: 965ms
# 518:	learn: 0.2977941	total: 1.04s	remaining: 964ms
# 519:	learn: 0.2977188	total: 1.04s	remaining: 961ms
# 520:	learn: 0.2976277	total: 1.04s	remaining: 959ms
# 521:	learn: 0.2975612	total: 1.04s	remaining: 957ms
# 522:	learn: 0.2974446	total: 1.05s	remaining: 955ms
# 523:	learn: 0.2973345	total: 1.05s	remaining: 952ms
# 524:	learn: 0.2972271	total: 1.05s	remaining: 950ms
# 525:	learn: 0.2971182	total: 1.05s	remaining: 948ms
# 526:	learn: 0.2970249	total: 1.05s	remaining: 946ms
# 527:	learn: 0.2969317	total: 1.06s	remaining: 944ms
# 528:	learn: 0.2968306	total: 1.06s	remaining: 942ms
# 529:	learn: 0.2967126	total: 1.06s	remaining: 940ms
# 530:	learn: 0.2966028	total: 1.06s	remaining: 938ms
# 531:	learn: 0.2965062	total: 1.06s	remaining: 935ms
# 532:	learn: 0.2963811	total: 1.06s	remaining: 933ms
# 533:	learn: 0.2962983	total: 1.07s	remaining: 931ms
# 534:	learn: 0.2961914	total: 1.07s	remaining: 929ms
# 535:	learn: 0.2961032	total: 1.07s	remaining: 927ms
# 536:	learn: 0.2959692	total: 1.07s	remaining: 924ms
# 537:	learn: 0.2958747	total: 1.07s	remaining: 922ms
# 538:	learn: 0.2958070	total: 1.07s	remaining: 920ms
# 539:	learn: 0.2957365	total: 1.08s	remaining: 918ms
# 540:	learn: 0.2955837	total: 1.08s	remaining: 916ms
# 541:	learn: 0.2955257	total: 1.08s	remaining: 914ms
# 542:	learn: 0.2954057	total: 1.08s	remaining: 912ms
# 543:	learn: 0.2953092	total: 1.08s	remaining: 909ms
# 544:	learn: 0.2952460	total: 1.09s	remaining: 907ms
# 545:	learn: 0.2952027	total: 1.09s	remaining: 905ms
# 546:	learn: 0.2950788	total: 1.09s	remaining: 903ms
# 547:	learn: 0.2949819	total: 1.09s	remaining: 901ms
# 548:	learn: 0.2949128	total: 1.09s	remaining: 898ms
# 549:	learn: 0.2948158	total: 1.09s	remaining: 896ms
# 550:	learn: 0.2946407	total: 1.1s	remaining: 894ms
# 551:	learn: 0.2945515	total: 1.1s	remaining: 892ms
# 552:	learn: 0.2944493	total: 1.1s	remaining: 890ms
# 553:	learn: 0.2943765	total: 1.1s	remaining: 887ms
# 554:	learn: 0.2943190	total: 1.1s	remaining: 885ms
# 555:	learn: 0.2941960	total: 1.1s	remaining: 883ms
# 556:	learn: 0.2940583	total: 1.11s	remaining: 881ms
# 557:	learn: 0.2939472	total: 1.11s	remaining: 879ms
# 558:	learn: 0.2938596	total: 1.11s	remaining: 877ms
# 559:	learn: 0.2937618	total: 1.11s	remaining: 875ms
# 560:	learn: 0.2936530	total: 1.11s	remaining: 873ms
# 561:	learn: 0.2935934	total: 1.12s	remaining: 871ms
# 562:	learn: 0.2935234	total: 1.12s	remaining: 868ms
# 563:	learn: 0.2933233	total: 1.12s	remaining: 866ms
# 564:	learn: 0.2932617	total: 1.12s	remaining: 864ms
# 565:	learn: 0.2931077	total: 1.12s	remaining: 862ms
# 566:	learn: 0.2930285	total: 1.13s	remaining: 860ms
# 567:	learn: 0.2929604	total: 1.13s	remaining: 857ms
# 568:	learn: 0.2928788	total: 1.13s	remaining: 855ms
# 569:	learn: 0.2928196	total: 1.13s	remaining: 853ms
# 570:	learn: 0.2926918	total: 1.13s	remaining: 851ms
# 571:	learn: 0.2926067	total: 1.14s	remaining: 849ms
# 572:	learn: 0.2924696	total: 1.14s	remaining: 847ms
# 573:	learn: 0.2923918	total: 1.14s	remaining: 845ms
# 574:	learn: 0.2922846	total: 1.14s	remaining: 843ms
# 575:	learn: 0.2921597	total: 1.14s	remaining: 841ms
# 576:	learn: 0.2920380	total: 1.14s	remaining: 839ms
# 577:	learn: 0.2919396	total: 1.15s	remaining: 837ms
# 578:	learn: 0.2918514	total: 1.15s	remaining: 834ms
# 579:	learn: 0.2917571	total: 1.15s	remaining: 832ms
# 580:	learn: 0.2916349	total: 1.15s	remaining: 830ms
# 581:	learn: 0.2915160	total: 1.15s	remaining: 828ms
# 582:	learn: 0.2913903	total: 1.15s	remaining: 826ms
# 583:	learn: 0.2913225	total: 1.16s	remaining: 824ms
# 584:	learn: 0.2912337	total: 1.16s	remaining: 822ms
# 585:	learn: 0.2911283	total: 1.16s	remaining: 819ms
# 586:	learn: 0.2910660	total: 1.16s	remaining: 817ms
# 587:	learn: 0.2910224	total: 1.16s	remaining: 815ms
# 588:	learn: 0.2909014	total: 1.17s	remaining: 813ms
# 589:	learn: 0.2907938	total: 1.17s	remaining: 811ms
# 590:	learn: 0.2906535	total: 1.17s	remaining: 809ms
# ...
# 693:	learn: 0.2839112	total: 1.49s	remaining: 658ms
# 694:	learn: 0.2837878	total: 1.49s	remaining: 655ms
# 695:	learn: 0.2837152	total: 1.5s	remaining: 653ms
# 696:	learn: 0.2836210	total: 1.5s	remaining: 651ms
# 697:	learn: 0.2835173	total: 1.5s	remaining: 649ms
# 698:	learn: 0.2834598	total: 1.5s	remaining: 646ms
# 699:	learn: 0.2834401	total: 1.5s	remaining: 644ms
# 700:	learn: 0.2833403	total: 1.5s	remaining: 642ms
# 701:	learn: 0.2832905	total: 1.51s	remaining: 640ms
# 702:	learn: 0.2831751	total: 1.51s	remaining: 637ms
# 703:	learn: 0.2830793	total: 1.51s	remaining: 635ms
# 704:	learn: 0.2830114	total: 1.51s	remaining: 633ms
# 705:	learn: 0.2829192	total: 1.51s	remaining: 631ms
# 706:	learn: 0.2828182	total: 1.52s	remaining: 629ms
# 707:	learn: 0.2827837	total: 1.52s	remaining: 626ms
# 708:	learn: 0.2827203	total: 1.52s	remaining: 624ms
# 709:	learn: 0.2826552	total: 1.52s	remaining: 622ms
# 710:	learn: 0.2825390	total: 1.52s	remaining: 620ms
# 711:	learn: 0.2824327	total: 1.52s	remaining: 617ms
# 712:	learn: 0.2823095	total: 1.53s	remaining: 615ms
# 713:	learn: 0.2822458	total: 1.53s	remaining: 613ms
# 714:	learn: 0.2821702	total: 1.53s	remaining: 610ms
# 715:	learn: 0.2821389	total: 1.53s	remaining: 608ms
# 716:	learn: 0.2820559	total: 1.53s	remaining: 606ms
# 717:	learn: 0.2819995	total: 1.54s	remaining: 604ms
# 718:	learn: 0.2819373	total: 1.54s	remaining: 602ms
# 719:	learn: 0.2818354	total: 1.54s	remaining: 600ms
# 720:	learn: 0.2817254	total: 1.54s	remaining: 597ms
# 721:	learn: 0.2816649	total: 1.54s	remaining: 595ms
# 722:	learn: 0.2815657	total: 1.55s	remaining: 593ms
# 723:	learn: 0.2815116	total: 1.55s	remaining: 591ms
# 724:	learn: 0.2814301	total: 1.55s	remaining: 588ms
# 725:	learn: 0.2813551	total: 1.55s	remaining: 586ms
# 726:	learn: 0.2812882	total: 1.55s	remaining: 584ms
# 727:	learn: 0.2811624	total: 1.56s	remaining: 582ms
# 728:	learn: 0.2811112	total: 1.56s	remaining: 580ms
# 729:	learn: 0.2810122	total: 1.56s	remaining: 578ms
# 730:	learn: 0.2809332	total: 1.56s	remaining: 575ms
# 731:	learn: 0.2808108	total: 1.56s	remaining: 573ms
# 732:	learn: 0.2807897	total: 1.57s	remaining: 571ms
# 733:	learn: 0.2806365	total: 1.57s	remaining: 569ms
# 734:	learn: 0.2805890	total: 1.57s	remaining: 566ms
# 735:	learn: 0.2803823	total: 1.57s	remaining: 564ms
# 736:	learn: 0.2803265	total: 1.57s	remaining: 562ms
# 737:	learn: 0.2802407	total: 1.58s	remaining: 560ms
# 738:	learn: 0.2801277	total: 1.58s	remaining: 557ms
# 739:	learn: 0.2800867	total: 1.58s	remaining: 555ms
# 740:	learn: 0.2800343	total: 1.58s	remaining: 553ms
# 741:	learn: 0.2799438	total: 1.58s	remaining: 551ms
# 742:	learn: 0.2798351	total: 1.58s	remaining: 549ms
# 743:	learn: 0.2797112	total: 1.59s	remaining: 546ms
# 744:	learn: 0.2796460	total: 1.59s	remaining: 544ms
# 745:	learn: 0.2795844	total: 1.59s	remaining: 542ms
# 746:	learn: 0.2794804	total: 1.59s	remaining: 540ms
# 747:	learn: 0.2793456	total: 1.6s	remaining: 538ms
# 748:	learn: 0.2792517	total: 1.6s	remaining: 536ms
# 749:	learn: 0.2791801	total: 1.6s	remaining: 533ms
# 750:	learn: 0.2791444	total: 1.6s	remaining: 531ms
# 751:	learn: 0.2790571	total: 1.6s	remaining: 529ms
# 752:	learn: 0.2789808	total: 1.61s	remaining: 527ms
# 753:	learn: 0.2788908	total: 1.61s	remaining: 525ms
# 754:	learn: 0.2788277	total: 1.61s	remaining: 523ms
# 755:	learn: 0.2786313	total: 1.61s	remaining: 520ms
# 756:	learn: 0.2785774	total: 1.61s	remaining: 518ms
# 757:	learn: 0.2785240	total: 1.61s	remaining: 516ms
# 758:	learn: 0.2784622	total: 1.62s	remaining: 514ms
# 759:	learn: 0.2784175	total: 1.62s	remaining: 511ms
# 760:	learn: 0.2783374	total: 1.62s	remaining: 509ms
# 761:	learn: 0.2782615	total: 1.62s	remaining: 507ms
# 762:	learn: 0.2781790	total: 1.63s	remaining: 505ms
# 763:	learn: 0.2780890	total: 1.63s	remaining: 503ms
# 764:	learn: 0.2779255	total: 1.63s	remaining: 501ms
# 765:	learn: 0.2778389	total: 1.63s	remaining: 499ms
# 766:	learn: 0.2777689	total: 1.63s	remaining: 496ms
# 767:	learn: 0.2776821	total: 1.64s	remaining: 494ms
# 768:	learn: 0.2775935	total: 1.64s	remaining: 492ms
# 769:	learn: 0.2774941	total: 1.64s	remaining: 490ms
# 770:	learn: 0.2774324	total: 1.64s	remaining: 488ms
# 771:	learn: 0.2773566	total: 1.64s	remaining: 485ms
# 772:	learn: 0.2772739	total: 1.65s	remaining: 483ms
# 773:	learn: 0.2771854	total: 1.65s	remaining: 481ms
# 774:	learn: 0.2771453	total: 1.65s	remaining: 479ms
# 775:	learn: 0.2770836	total: 1.65s	remaining: 477ms
# 776:	learn: 0.2769998	total: 1.65s	remaining: 474ms
# 777:	learn: 0.2769283	total: 1.65s	remaining: 472ms
# 778:	learn: 0.2768932	total: 1.66s	remaining: 470ms
# 779:	learn: 0.2768351	total: 1.66s	remaining: 468ms
# 780:	learn: 0.2767348	total: 1.66s	remaining: 466ms
# 781:	learn: 0.2766706	total: 1.66s	remaining: 463ms
# 782:	learn: 0.2766115	total: 1.66s	remaining: 461ms
# 783:	learn: 0.2765476	total: 1.67s	remaining: 459ms
# 784:	learn: 0.2764659	total: 1.67s	remaining: 457ms
# 785:	learn: 0.2763589	total: 1.67s	remaining: 455ms
# 786:	learn: 0.2762885	total: 1.67s	remaining: 453ms
# 787:	learn: 0.2762249	total: 1.67s	remaining: 450ms
# 788:	learn: 0.2761640	total: 1.68s	remaining: 448ms
# 789:	learn: 0.2760995	total: 1.68s	remaining: 446ms
# 790:	learn: 0.2760483	total: 1.68s	remaining: 444ms
# 791:	learn: 0.2759476	total: 1.68s	remaining: 442ms
# 792:	learn: 0.2758841	total: 1.68s	remaining: 439ms
# 793:	learn: 0.2758070	total: 1.69s	remaining: 437ms
# 794:	learn: 0.2757078	total: 1.69s	remaining: 435ms
# 795:	learn: 0.2756321	total: 1.69s	remaining: 433ms
# 796:	learn: 0.2755029	total: 1.69s	remaining: 431ms
# 797:	learn: 0.2754341	total: 1.69s	remaining: 429ms
# 798:	learn: 0.2753634	total: 1.7s	remaining: 426ms
# 799:	learn: 0.2753101	total: 1.7s	remaining: 424ms
# 800:	learn: 0.2752438	total: 1.7s	remaining: 422ms
# 801:	learn: 0.2751379	total: 1.7s	remaining: 420ms
# 802:	learn: 0.2750987	total: 1.7s	remaining: 418ms
# 803:	learn: 0.2750134	total: 1.7s	remaining: 416ms
# 804:	learn: 0.2749313	total: 1.71s	remaining: 413ms
# 805:	learn: 0.2748525	total: 1.71s	remaining: 411ms
# 806:	learn: 0.2748044	total: 1.71s	remaining: 409ms
# 807:	learn: 0.2747373	total: 1.71s	remaining: 407ms
# 808:	learn: 0.2746570	total: 1.71s	remaining: 405ms
# 809:	learn: 0.2745902	total: 1.72s	remaining: 403ms
# 810:	learn: 0.2745551	total: 1.72s	remaining: 400ms
# 811:	learn: 0.2744659	total: 1.72s	remaining: 398ms
# 812:	learn: 0.2743713	total: 1.72s	remaining: 396ms
# 813:	learn: 0.2743013	total: 1.72s	remaining: 394ms
# 814:	learn: 0.2742349	total: 1.73s	remaining: 392ms
# 815:	learn: 0.2741877	total: 1.73s	remaining: 390ms
# 816:	learn: 0.2740950	total: 1.73s	remaining: 387ms
# 817:	learn: 0.2740193	total: 1.73s	remaining: 385ms
# 818:	learn: 0.2739484	total: 1.73s	remaining: 383ms
# 819:	learn: 0.2738676	total: 1.74s	remaining: 381ms
# 820:	learn: 0.2737654	total: 1.74s	remaining: 379ms
# 821:	learn: 0.2736936	total: 1.74s	remaining: 377ms
# 822:	learn: 0.2736276	total: 1.74s	remaining: 375ms
# 823:	learn: 0.2735589	total: 1.74s	remaining: 372ms
# 824:	learn: 0.2735148	total: 1.75s	remaining: 370ms
# 825:	learn: 0.2734203	total: 1.75s	remaining: 368ms
# 826:	learn: 0.2733415	total: 1.75s	remaining: 366ms
# 827:	learn: 0.2732650	total: 1.75s	remaining: 364ms
# 828:	learn: 0.2732365	total: 1.75s	remaining: 362ms
# 829:	learn: 0.2731602	total: 1.75s	remaining: 360ms
# 830:	learn: 0.2731092	total: 1.76s	remaining: 357ms
# 831:	learn: 0.2730341	total: 1.76s	remaining: 355ms
# 832:	learn: 0.2729381	total: 1.76s	remaining: 353ms
# 833:	learn: 0.2728468	total: 1.76s	remaining: 351ms
# 834:	learn: 0.2727595	total: 1.76s	remaining: 349ms
# 835:	learn: 0.2726854	total: 1.77s	remaining: 347ms
# 836:	learn: 0.2726032	total: 1.77s	remaining: 345ms
# 837:	learn: 0.2725452	total: 1.77s	remaining: 343ms
# 838:	learn: 0.2724901	total: 1.77s	remaining: 340ms
# 839:	learn: 0.2724242	total: 1.78s	remaining: 338ms
# 840:	learn: 0.2723772	total: 1.78s	remaining: 336ms
# 841:	learn: 0.2722792	total: 1.78s	remaining: 334ms
# 842:	learn: 0.2722282	total: 1.78s	remaining: 332ms
# 843:	learn: 0.2721288	total: 1.78s	remaining: 330ms
# 844:	learn: 0.2720358	total: 1.78s	remaining: 328ms
# 845:	learn: 0.2719952	total: 1.79s	remaining: 325ms
# 846:	learn: 0.2719033	total: 1.79s	remaining: 323ms
# 847:	learn: 0.2718296	total: 1.79s	remaining: 321ms
# 848:	learn: 0.2717667	total: 1.79s	remaining: 319ms
# 849:	learn: 0.2716497	total: 1.79s	remaining: 317ms
# 850:	learn: 0.2715635	total: 1.8s	remaining: 315ms
# 851:	learn: 0.2714411	total: 1.8s	remaining: 313ms
# 852:	learn: 0.2713860	total: 1.8s	remaining: 310ms
# 853:	learn: 0.2713316	total: 1.8s	remaining: 308ms
# 854:	learn: 0.2712606	total: 1.8s	remaining: 306ms
# 855:	learn: 0.2711953	total: 1.81s	remaining: 304ms
# 856:	learn: 0.2711040	total: 1.81s	remaining: 302ms
# 857:	learn: 0.2710454	total: 1.81s	remaining: 300ms
# 858:	learn: 0.2709467	total: 1.81s	remaining: 298ms
# 859:	learn: 0.2708634	total: 1.81s	remaining: 295ms
# 860:	learn: 0.2707846	total: 1.82s	remaining: 293ms
# 861:	learn: 0.2706949	total: 1.82s	remaining: 291ms
# 862:	learn: 0.2706311	total: 1.82s	remaining: 289ms
# 863:	learn: 0.2705596	total: 1.82s	remaining: 287ms
# 864:	learn: 0.2704674	total: 1.82s	remaining: 285ms
# 865:	learn: 0.2703915	total: 1.83s	remaining: 283ms
# 866:	learn: 0.2703033	total: 1.83s	remaining: 280ms
# 867:	learn: 0.2702112	total: 1.83s	remaining: 278ms
# 868:	learn: 0.2700922	total: 1.83s	remaining: 276ms
# 869:	learn: 0.2699888	total: 1.83s	remaining: 274ms
# 870:	learn: 0.2699207	total: 1.84s	remaining: 272ms
# 871:	learn: 0.2698257	total: 1.84s	remaining: 270ms
# 872:	learn: 0.2697251	total: 1.84s	remaining: 268ms
# 873:	learn: 0.2696780	total: 1.84s	remaining: 266ms
# 874:	learn: 0.2695333	total: 1.84s	remaining: 263ms
# 875:	learn: 0.2694317	total: 1.85s	remaining: 261ms
# 876:	learn: 0.2693196	total: 1.85s	remaining: 259ms
# 877:	learn: 0.2692994	total: 1.85s	remaining: 257ms
# 878:	learn: 0.2692414	total: 1.85s	remaining: 255ms
# 879:	learn: 0.2691553	total: 1.85s	remaining: 253ms
# 880:	learn: 0.2690543	total: 1.85s	remaining: 251ms
# 881:	learn: 0.2689637	total: 1.86s	remaining: 249ms
# 882:	learn: 0.2688882	total: 1.86s	remaining: 246ms
# 883:	learn: 0.2687951	total: 1.86s	remaining: 244ms
# 884:	learn: 0.2687401	total: 1.86s	remaining: 242ms
# 885:	learn: 0.2686610	total: 1.86s	remaining: 240ms
# 886:	learn: 0.2686092	total: 1.87s	remaining: 238ms
# 887:	learn: 0.2685176	total: 1.87s	remaining: 236ms
# 888:	learn: 0.2684780	total: 1.87s	remaining: 234ms
# 889:	learn: 0.2684385	total: 1.87s	remaining: 231ms
# 890:	learn: 0.2683947	total: 1.88s	remaining: 229ms
# 891:	learn: 0.2683299	total: 1.88s	remaining: 227ms
# 892:	learn: 0.2682838	total: 1.88s	remaining: 225ms
# 893:	learn: 0.2681822	total: 1.88s	remaining: 223ms
# 894:	learn: 0.2681289	total: 1.88s	remaining: 221ms
# 895:	learn: 0.2680577	total: 1.89s	remaining: 219ms
# 896:	learn: 0.2679856	total: 1.89s	remaining: 217ms
# 897:	learn: 0.2678552	total: 1.89s	remaining: 215ms
# 898:	learn: 0.2678069	total: 1.89s	remaining: 212ms
# 899:	learn: 0.2677763	total: 1.89s	remaining: 210ms
# 900:	learn: 0.2677105	total: 1.9s	remaining: 208ms
# 901:	learn: 0.2676365	total: 1.9s	remaining: 206ms
# 902:	learn: 0.2675588	total: 1.9s	remaining: 204ms
# 903:	learn: 0.2674765	total: 1.9s	remaining: 202ms
# 904:	learn: 0.2674344	total: 1.9s	remaining: 200ms
# 905:	learn: 0.2673499	total: 1.9s	remaining: 198ms
# 906:	learn: 0.2672340	total: 1.91s	remaining: 195ms
# 907:	learn: 0.2671508	total: 1.91s	remaining: 193ms
# 908:	learn: 0.2670161	total: 1.91s	remaining: 191ms
# 909:	learn: 0.2669614	total: 1.91s	remaining: 189ms
# 910:	learn: 0.2669146	total: 1.91s	remaining: 187ms
# 911:	learn: 0.2668294	total: 1.92s	remaining: 185ms
# 912:	learn: 0.2667476	total: 1.92s	remaining: 183ms
# 913:	learn: 0.2665774	total: 1.92s	remaining: 181ms
# 914:	learn: 0.2664974	total: 1.92s	remaining: 178ms
# 915:	learn: 0.2664301	total: 1.92s	remaining: 176ms
# 916:	learn: 0.2663813	total: 1.93s	remaining: 174ms
# 917:	learn: 0.2663253	total: 1.93s	remaining: 172ms
# 918:	learn: 0.2662667	total: 1.93s	remaining: 170ms
# 919:	learn: 0.2661736	total: 1.93s	remaining: 168ms
# 920:	learn: 0.2660751	total: 1.93s	remaining: 166ms
# 921:	learn: 0.2660405	total: 1.93s	remaining: 164ms
# 922:	learn: 0.2659599	total: 1.94s	remaining: 162ms
# 923:	learn: 0.2659059	total: 1.94s	remaining: 160ms
# 924:	learn: 0.2658428	total: 1.94s	remaining: 157ms
# 925:	learn: 0.2657305	total: 1.94s	remaining: 155ms
# 926:	learn: 0.2656530	total: 1.95s	remaining: 153ms
# 927:	learn: 0.2656003	total: 1.95s	remaining: 151ms
# 928:	learn: 0.2655268	total: 1.95s	remaining: 149ms
# 929:	learn: 0.2654429	total: 1.95s	remaining: 147ms
# 930:	learn: 0.2653751	total: 1.95s	remaining: 145ms
# 931:	learn: 0.2653284	total: 1.96s	remaining: 143ms
# 932:	learn: 0.2652936	total: 1.96s	remaining: 141ms
# 933:	learn: 0.2651911	total: 1.96s	remaining: 138ms
# 934:	learn: 0.2651389	total: 1.96s	remaining: 136ms
# 935:	learn: 0.2650540	total: 1.96s	remaining: 134ms
# 936:	learn: 0.2650209	total: 1.97s	remaining: 132ms
# 937:	learn: 0.2649728	total: 1.97s	remaining: 130ms
# 938:	learn: 0.2648847	total: 1.97s	remaining: 128ms
# 939:	learn: 0.2647583	total: 1.97s	remaining: 126ms
# 940:	learn: 0.2647234	total: 1.97s	remaining: 124ms
# 941:	learn: 0.2646631	total: 1.98s	remaining: 122ms
# 942:	learn: 0.2645935	total: 1.98s	remaining: 120ms
# 943:	learn: 0.2644990	total: 1.98s	remaining: 117ms
# 944:	learn: 0.2644322	total: 1.98s	remaining: 115ms
# 945:	learn: 0.2643955	total: 1.98s	remaining: 113ms
# 946:	learn: 0.2643526	total: 1.98s	remaining: 111ms
# 947:	learn: 0.2642094	total: 1.99s	remaining: 109ms
# 948:	learn: 0.2641605	total: 1.99s	remaining: 107ms
# 949:	learn: 0.2641108	total: 1.99s	remaining: 105ms
# 950:	learn: 0.2640443	total: 1.99s	remaining: 103ms
# 951:	learn: 0.2639694	total: 1.99s	remaining: 101ms
# 952:	learn: 0.2638717	total: 2s	remaining: 98.4ms
# 953:	learn: 0.2638427	total: 2s	remaining: 96.3ms
# 954:	learn: 0.2637331	total: 2s	remaining: 94.2ms
# 955:	learn: 0.2636570	total: 2s	remaining: 92.1ms
# 956:	learn: 0.2635536	total: 2s	remaining: 90ms
# 957:	learn: 0.2634837	total: 2s	remaining: 87.9ms
# 958:	learn: 0.2634504	total: 2.01s	remaining: 85.8ms
# 959:	learn: 0.2633902	total: 2.01s	remaining: 83.7ms
# 960:	learn: 0.2633136	total: 2.01s	remaining: 81.6ms
# 961:	learn: 0.2632534	total: 2.01s	remaining: 79.5ms
# 962:	learn: 0.2631996	total: 2.02s	remaining: 77.4ms
# 963:	learn: 0.2631310	total: 2.02s	remaining: 75.3ms
# 964:	learn: 0.2630607	total: 2.02s	remaining: 73.3ms
# 965:	learn: 0.2629734	total: 2.02s	remaining: 71.2ms
# 966:	learn: 0.2628827	total: 2.02s	remaining: 69.1ms
# 967:	learn: 0.2628309	total: 2.02s	remaining: 67ms
# 968:	learn: 0.2626916	total: 2.03s	remaining: 64.9ms
# 969:	learn: 0.2626276	total: 2.03s	remaining: 62.8ms
# 970:	learn: 0.2625820	total: 2.03s	remaining: 60.7ms
# 971:	learn: 0.2625342	total: 2.03s	remaining: 58.6ms
# 972:	learn: 0.2625016	total: 2.03s	remaining: 56.5ms
# 973:	learn: 0.2624299	total: 2.04s	remaining: 54.4ms
# 974:	learn: 0.2623307	total: 2.04s	remaining: 52.3ms
# 975:	learn: 0.2622617	total: 2.04s	remaining: 50.2ms
# 976:	learn: 0.2622187	total: 2.04s	remaining: 48.1ms
# 977:	learn: 0.2621681	total: 2.04s	remaining: 46ms
# 978:	learn: 0.2621208	total: 2.05s	remaining: 43.9ms
# 979:	learn: 0.2620975	total: 2.05s	remaining: 41.8ms
# 980:	learn: 0.2620372	total: 2.05s	remaining: 39.7ms
# 981:	learn: 0.2619728	total: 2.05s	remaining: 37.6ms
# 982:	learn: 0.2619031	total: 2.05s	remaining: 35.5ms
# 983:	learn: 0.2618277	total: 2.06s	remaining: 33.4ms
# 984:	learn: 0.2617717	total: 2.06s	remaining: 31.3ms
# 985:	learn: 0.2616952	total: 2.06s	remaining: 29.2ms
# 986:	learn: 0.2616245	total: 2.06s	remaining: 27.2ms
# 987:	learn: 0.2615153	total: 2.06s	remaining: 25.1ms
# 988:	learn: 0.2614617	total: 2.06s	remaining: 23ms
# 989:	learn: 0.2613868	total: 2.07s	remaining: 20.9ms
# 990:	learn: 0.2612680	total: 2.07s	remaining: 18.8ms
# 991:	learn: 0.2611924	total: 2.07s	remaining: 16.7ms
# 992:	learn: 0.2611104	total: 2.07s	remaining: 14.6ms
# 993:	learn: 0.2610344	total: 2.07s	remaining: 12.5ms
# 994:	learn: 0.2609845	total: 2.08s	remaining: 10.4ms
# 995:	learn: 0.2609265	total: 2.08s	remaining: 8.35ms
# 996:	learn: 0.2608580	total: 2.08s	remaining: 6.26ms
# 997:	learn: 0.2608067	total: 2.08s	remaining: 4.17ms
# 998:	learn: 0.2607478	total: 2.08s	remaining: 2.09ms
# 999:	learn: 0.2606984	total: 2.09s	remaining: 0us

# %% [markdown]
# Stratified cross-validation is essential when you’re working with imbalanced classes, like in the Telco Customer Churn dataset where many more customers may have stayed than churned.

# %% [markdown]
# ## 4. Using Metrics to Evaluate on the Training Set

# %% [markdown]
# ### 4.1. Displaying results as a table

# %%
results_df = pd.DataFrame(results)

print(results_df)

# Round numeric metrics
results_df[['Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC AUC', 'PR AUC']] = results_df[['Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC AUC', 'PR AUC']].round(4)

# Style only the numeric columns (exclude Confusion Matrix)
styled_df = results_df.style\
    .background_gradient(cmap="Wistia", subset=['Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC AUC', 'PR AUC'])\
    .highlight_max(axis=0, color='#ffd1a9', subset=['Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC AUC', 'PR AUC'])\
    .format(precision=4, subset=['Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC AUC', 'PR AUC'])\
    .set_properties(**{'color': 'black'}, subset=['Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC AUC', 'PR AUC'])


styled_df
# Out:
#                     Model  Accuracy  Precision    Recall  F1 Score   ROC AUC  \
# 0      LogisticRegression  0.771169   0.753536  0.806032  0.778670  0.853481
# 1                     SVC  0.766051   0.739773  0.820974  0.778158  0.850555
# 2  DecisionTreeClassifier  0.803404   0.801958  0.806033  0.803895  0.804386
# 3  RandomForestClassifier  0.845878   0.849451  0.840896  0.845070  0.920330
# 4           XGBClassifier  0.847676   0.844131  0.852792  0.848438  0.925265
# 5      CatBoostClassifier  0.851688   0.847465  0.857775  0.852564  0.930086
#
#      PR AUC
# 0  0.834519
# 1  0.832692
# 2  0.744433
# 3  0.909266
# 4  0.930683
# 5  0.933987
# <style type="text/css">
# #T_35fb7_row0_col1 {
#   background-color: #eafa63;
#   color: #000000;
#   color: black;
# }
# #T_35fb7_row0_col2 {
#   background-color: #f1f44b;
#   color: #000000;
#   color: black;
# }
# #T_35fb7_row0_col3, #T_35fb7_row1_col1, #T_35fb7_row1_col2, #T_35fb7_row1_col4, #T_35fb7_row2_col3, #T_35fb7_row2_col5, #T_35fb7_row2_col6 {
#   background-color: #e4ff7a;
#   color: #000000;
#   color: black;
# }
# #T_35fb7_row0_col4 {
#   background-color: #e4ff78;
#   color: #000000;
#   color: black;
# }
# #T_35fb7_row0_col5 {
#   background-color: #ffd00c;
#   color: #000000;
#   color: black;
# }
# #T_35fb7_row0_col6 {
#   background-color: #ffc103;
#   color: #000000;
#   color: black;
# }
# #T_35fb7_row1_col3 {
#   background-color: #ffe116;
#   color: #000000;
#   color: black;
# }
# #T_35fb7_row1_col5 {
#   background-color: #ffd40e;
#   color: #000000;
#   color: black;
# }
# #T_35fb7_row1_col6 {
#   background-color: #ffc303;
#   color: #000000;
#   color: black;
# }
# #T_35fb7_row2_col1 {
#   background-color: #ffc807;
#   color: #000000;
#   color: black;
# }
# #T_35fb7_row2_col2 {
#   background-color: #ffb500;
#   color: #000000;
#   color: black;
# }
# #T_35fb7_row2_col4 {
#   background-color: #ffd810;
#   color: #000000;
#   color: black;
# }
# #T_35fb7_row3_col1 {
#   background-color: #fd8800;
#   color: #f1f1f1;
#   color: black;
# }
# #T_35fb7_row3_col2, #T_35fb7_row5_col1, #T_35fb7_row5_col3, #T_35fb7_row5_col4, #T_35fb7_row5_col5, #T_35fb7_row5_col6 {
#   background-color: #fc7f00;
#   color: #f1f1f1;
#   background-color: #ffd1a9;
#   color: black;
# }
# #T_35fb7_row3_col3 {
#   background-color: #ffa900;
#   color: #000000;
#   color: black;
# }
# #T_35fb7_row3_col4 {
#   background-color: #fd8c00;
#   color: #f1f1f1;
#   color: black;
# }
# #T_35fb7_row3_col5 {
#   background-color: #fd8900;
#   color: #f1f1f1;
#   color: black;
# }
# #T_35fb7_row3_col6 {
#   background-color: #fe9000;
#   color: #000000;
#   color: black;
# }
# #T_35fb7_row4_col1, #T_35fb7_row4_col2 {
#   background-color: #fd8500;
#   color: #f1f1f1;
#   color: black;
# }
# #T_35fb7_row4_col3 {
#   background-color: #fd8b00;
#   color: #f1f1f1;
#   color: black;
# }
# #T_35fb7_row4_col4 {
#   background-color: #fd8600;
#   color: #f1f1f1;
#   color: black;
# }
# #T_35fb7_row4_col5 {
#   background-color: #fc8400;
#   color: #f1f1f1;
#   color: black;
# }
# #T_35fb7_row4_col6, #T_35fb7_row5_col2 {
#   background-color: #fc8100;
#   color: #f1f1f1;
#   color: black;
# }
# </style>
# <table id="T_35fb7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35fb7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_35fb7_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_35fb7_level0_col2" class="col_heading level0 col2" >Precision</th>
#       <th id="T_35fb7_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_35fb7_level0_col4" class="col_heading level0 col4" >F1 Score</th>
#       <th id="T_35fb7_level0_col5" class="col_heading level0 col5" >ROC AUC</th>
#       <th id="T_35fb7_level0_col6" class="col_heading level0 col6" >PR AUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35fb7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35fb7_row0_col0" class="data row0 col0" >LogisticRegression</td>
#       <td id="T_35fb7_row0_col1" class="data row0 col1" >0.7712</td>
#       <td id="T_35fb7_row0_col2" class="data row0 col2" >0.7535</td>
#       <td id="T_35fb7_row0_col3" class="data row0 col3" >0.8060</td>
#       <td id="T_35fb7_row0_col4" class="data row0 col4" >0.7787</td>
#       <td id="T_35fb7_row0_col5" class="data row0 col5" >0.8535</td>
#       <td id="T_35fb7_row0_col6" class="data row0 col6" >0.8345</td>
#     </tr>
#     <tr>
#       <th id="T_35fb7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_35fb7_row1_col0" class="data row1 col0" >SVC</td>
#       <td id="T_35fb7_row1_col1" class="data row1 col1" >0.7661</td>
#       <td id="T_35fb7_row1_col2" class="data row1 col2" >0.7398</td>
#       <td id="T_35fb7_row1_col3" class="data row1 col3" >0.8210</td>
#       <td id="T_35fb7_row1_col4" class="data row1 col4" >0.7782</td>
#       <td id="T_35fb7_row1_col5" class="data row1 col5" >0.8506</td>
#       <td id="T_35fb7_row1_col6" class="data row1 col6" >0.8327</td>
#     </tr>
#     <tr>
#       <th id="T_35fb7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_35fb7_row2_col0" class="data row2 col0" >DecisionTreeClassifier</td>
#       <td id="T_35fb7_row2_col1" class="data row2 col1" >0.8034</td>
#       <td id="T_35fb7_row2_col2" class="data row2 col2" >0.8020</td>
#       <td id="T_35fb7_row2_col3" class="data row2 col3" >0.8060</td>
#       <td id="T_35fb7_row2_col4" class="data row2 col4" >0.8039</td>
#       <td id="T_35fb7_row2_col5" class="data row2 col5" >0.8044</td>
#       <td id="T_35fb7_row2_col6" class="data row2 col6" >0.7444</td>
#     </tr>
#     <tr>
#       <th id="T_35fb7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_35fb7_row3_col0" class="data row3 col0" >RandomForestClassifier</td>
#       <td id="T_35fb7_row3_col1" class="data row3 col1" >0.8459</td>
#       <td id="T_35fb7_row3_col2" class="data row3 col2" >0.8495</td>
#       <td id="T_35fb7_row3_col3" class="data row3 col3" >0.8409</td>
#       <td id="T_35fb7_row3_col4" class="data row3 col4" >0.8451</td>
#       <td id="T_35fb7_row3_col5" class="data row3 col5" >0.9203</td>
#       <td id="T_35fb7_row3_col6" class="data row3 col6" >0.9093</td>
#     </tr>
#     <tr>
#       <th id="T_35fb7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_35fb7_row4_col0" class="data row4 col0" >XGBClassifier</td>
#       <td id="T_35fb7_row4_col1" class="data row4 col1" >0.8477</td>
#       <td id="T_35fb7_row4_col2" class="data row4 col2" >0.8441</td>
#       <td id="T_35fb7_row4_col3" class="data row4 col3" >0.8528</td>
#       <td id="T_35fb7_row4_col4" class="data row4 col4" >0.8484</td>
#       <td id="T_35fb7_row4_col5" class="data row4 col5" >0.9253</td>
#       <td id="T_35fb7_row4_col6" class="data row4 col6" >0.9307</td>
#     </tr>
#     <tr>
#       <th id="T_35fb7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_35fb7_row5_col0" class="data row5 col0" >CatBoostClassifier</td>
#       <td id="T_35fb7_row5_col1" class="data row5 col1" >0.8517</td>
#       <td id="T_35fb7_row5_col2" class="data row5 col2" >0.8475</td>
#       <td id="T_35fb7_row5_col3" class="data row5 col3" >0.8578</td>
#       <td id="T_35fb7_row5_col4" class="data row5 col4" >0.8526</td>
#       <td id="T_35fb7_row5_col5" class="data row5 col5" >0.9301</td>
#       <td id="T_35fb7_row5_col6" class="data row5 col6" >0.9340</td>
#     </tr>
#   </tbody>
# </table>

# %%
results_df = pd.DataFrame(results)
print(results_df)
# Out:
#                     Model  Accuracy  Precision    Recall  F1 Score  \
# 0      LogisticRegression  0.726066   0.490417  0.775401  0.600829
# 1                     SVC  0.715640   0.479100  0.796791  0.598394
# 2  DecisionTreeClassifier  0.740284   0.510236  0.577540  0.541806
# 3  RandomForestClassifier  0.772986   0.577652  0.543672  0.560147
# 4           XGBClassifier  0.766351   0.554662  0.614973  0.583263
# 5      CatBoostClassifier  0.783886   0.586207  0.636364  0.610256
#
#             Confusion Matrix
# 0  [[1097, 452], [126, 435]]
# 1  [[1063, 486], [114, 447]]
# 2  [[1238, 311], [237, 324]]
# 3  [[1326, 223], [256, 305]]
# 4  [[1272, 277], [216, 345]]
# 5  [[1297, 252], [204, 357]]

# %% [markdown]
# **Here's how you can interpret what you’ve got:**
#
# - Best Accuracy: CatBoostClassifier (0.7839)
# - Best F1 Score: Also CatBoostClassifier (0.6103), which suggests it's handling precision–recall trade-offs well.
# - Highest Recall: Again CatBoostClassifier (0.6364), which means it’s catching more positives (likely churners, if that’s your target).
# - If you’re optimizing for detecting churners (i.e. minimizing false negatives), recall and F1-score are most important — so CatBoostClassifier seems like your strongest performer.

# %% [markdown]
# ## 5. Model Tuning (Hyperparameter Optimization)

# %% [markdown]
# ## 6. Final Evaluation on Test Set (Unseen Data)

# %%
for model in models:
    model_name = model.__class__.__name__

    # Make predictions on the test set
    y_pred = model.predict(X_test) 
    y_proba = model.predict_proba(X_test)[:, 1]


    # Final evauation metrics
    final_accuracy = accuracy_score(y_test, y_pred)
    final_precision = precision_score(y_test, y_pred)
    final_recall = recall_score(y_test, y_pred)
    final_f1 = f1_score(y_test, y_pred)
    final_roc_auc = roc_auc_score(y_test, y_proba)
    final_avg_precision = average_precision_score(y_test, y_proba)

    results.append({
    'Model': model.__class__.__name__,
    'Accuracy': final_accuracy,
    'Precision': final_precision,
    'Recall': final_recall,
    'F1 Score': final_f1,
    'ROC AUC': final_roc_auc,
    'PR AUC': final_avg_precision
    })

# %% [markdown]
# ## 7. Visualising Results of The Test Set

# %% [markdown]
# ### 7.1. Confusion Matrices

# %%
from matplotlib.colors import LinearSegmentedColormap

# Define palette
colour_palette = LinearSegmentedColormap.from_list(
    "pink_orange",
    ["#fcd5ce", "#f9dcc4", "#f8c8dc", "#fac898", "#ffb997"]
)

# Plot confusion matrices
for result in results:
    cm = result['Confusion Matrix']
    model_name = result['Model']

    plt.figure(figsize=(4, 3))
    sns.heatmap(cm, annot=True, fmt='d', cmap=colour_palette,
                xticklabels=['Not Churn', 'Churn'],
                yticklabels=['Not Churn', 'Churn'],
                linewidths=0.5, linecolor='white', cbar=False)

    plt.title(f'Confusion Matrix: {model_name}', fontsize=12, fontweight='bold')
    plt.xlabel('Predicted Label', fontsize=10)
    plt.ylabel('True Label', fontsize=10)
    plt.xticks(fontsize=9)
    plt.yticks(fontsize=9, rotation=0)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 7.2. Visualizing FP vs FN per Model

# %%
conf_matrices = {
    'LogisticRegression': [[1097, 452], [126, 435]],
    'SVC': [[1063, 486], [114, 447]],
    'DecisionTreeClassifier': [[1238, 311], [237, 324]],  
    'RandomForestClassifier': [[1326, 223], [256, 305]],  
    'XGBClassifier': [[1272, 277], [216, 345]], 
    'CatBoostClassifier': [[1297, 252], [204, 357]] 
}

data = []

for model_name, matrix in conf_matrices.items():
    tn, fp = matrix[0]
    fn, tp = matrix[1]
    data.append({
        'Model': model_name,
        'False Positives': fp,
        'False Negatives': fn
    })

fp_fn_df = pd.DataFrame(data)

# %%
# Melt the dataframe for grouped bar chart
df_melted = fp_fn_df.melt(id_vars='Model', value_vars=['False Positives', 'False Negatives'],
                          var_name='Error Type', value_name='Count')

# Define soft pink and orange
custom_palette = ['#FFB6B9', '#FFDAC1']  # soft pink and peach

plt.figure(figsize=(10, 6))
sns.barplot(data=df_melted, x='Model', y='Count', hue='Error Type', palette=custom_palette)

plt.title('False Positives vs False Negatives per Model', fontsize=14)
plt.xticks(rotation=20)
plt.tight_layout()
plt.legend(title='Error Type')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# **Observation:**
#
# - The Logistic Regression and SVC models are wrongly predicting that loyal customers will churn.
# - High FP (light pink) → Model wrongly thinks loyal customers will churn.
# - High FN (peach) → Model fails to catch actual churners — costly mistake for a business.

# %% [markdown]
# ### 7.3. Classification Report

# %%
for model in models:
    print(f"Model: {model.__class__.__name__}")
    print(classification_report(y_test, y_pred))
    print("-" * 60)

# %% [markdown]
# ### 7.4. Visualising the ROC Curve

# %%
# Soft pinks and oranges
soft_colours = [
    '#fbb1bd',  # pastel pink
    '#ffd1a9',  # pastel orange
    '#fcd5ce',  # soft peach
    '#fae1dd',  # dusty rose
    '#ffe5ec',  # soft blush
    '#ffb997'   # melon orange
]

# %%
plt.figure(figsize=(8, 6))

for idx, model in enumerate(models):
    try:
        # Get probability scores
        if hasattr(model, "predict_proba"):
            y_proba = model.predict_proba(X_test)[:, 1]
        else:
            y_proba = model.decision_function(X_test)
    except: 
        continue # Skip if neither method is available

    # ROC Curves
    fpr, tpr = roc_curve(y_test, y_proba)
    auc = roc_auc_score(y_test, y_proba)

    colour = soft_colours[idex % len(soft_colours)]
    plt.plot(fpr, tpr, label=f"{model.__class__.__name__} (AUC = {auc:.2f})")

    
    # Plot formatting
    plt.plot([0, 1], [0, 1], 'k--', lw=1)
    plt.xlabel('False Positive Rate', fontsize=12)
    plt.ylabel('True Positive Rate', fontsize=12)
    plt.title('ROC Curves', fontsize=14, weight='bold')
    plt.legend(loc='lower right')
    plt.grid(True, linestyle='--', alpha=0.4)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 7.5. Visualising the Precision-Recall Curve

# %%
# Generate the curve
precision, recall, thresholds = precision_recall_curve(y_test, y_proba)
avg_precision = average_precision_score(y_test, y_proba)

# %%
# Plot the PR Curve

plt.figure(figsize=(8, 6)
           )
for idx, model in enumerate(models):
    try:
        if hasattr(model, "predict_proba"):
            y_proba = model.predict_proba(X_test)[:, 1]
        else:
            y_proba = model.decision_function(X_test)
    except:
        continue

    precision, recall, _ = precision_recall_curve(y_test, y_proba)
    avg_precision = average_precision_score(y_test, y_proba)

    colours = soft_colours[idx % len(soft_colours)]
    plt.plot(recall, precision, label=f"{model.__class__.__name__} (AP = {avg_precision:.2f})")


plt.xlabel("Recall", fontsize=12)
plt.ylabel("Precision", fontsize=12)
plt.title("Precision-Recall Curves", fontsize=14, weight='bold')
plt.grid(True, linestyle='--', alpha=0.4)
plt.legend(loc="best")
plt.tight_layout()
plt.show()
